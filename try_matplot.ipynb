# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np

# %%
x = np.linspace(0, 10, 100)

# %%
flg = plt.figure()
plt.plot(x,np.sin(x),'-')
plt.plot(x,np.cos(x),'--')
plt.plot(x,np.tan(x),'--')
plt.show()

# %%
p_x = np.random.rand(100)
p_x
# Out:
# array([0.97296321, 0.44783527, 0.79966459, 0.84107318, 0.36209644,
#        0.65938693, 0.75017834, 0.65195739, 0.94039995, 0.67080198,
#        0.93640928, 0.28292704, 0.19962682, 0.79220814, 0.65093588,
#        0.25487046, 0.14461357, 0.24324618, 0.00841755, 0.58332874,
#        0.85181682, 0.73292098, 0.89843709, 0.2203669 , 0.11618901,
#        0.30528897, 0.46698961, 0.13660854, 0.7210956 , 0.38408792,
#        0.0209548 , 0.90170646, 0.60257407, 0.42605095, 0.3246295 ,
#        0.34916516, 0.44976392, 0.34677713, 0.0949568 , 0.14911542,
#        0.18072225, 0.15318689, 0.39886517, 0.61584968, 0.09431976,
#        0.52905482, 0.61530691, 0.09676506, 0.14628321, 0.24685839,
#        0.23052546, 0.65999403, 0.72823515, 0.31240303, 0.66181634,
#        0.77300326, 0.71484251, 0.53960123, 0.51612532, 0.47192332,
#        0.9953296 , 0.8482073 , 0.01304359, 0.4198462 , 0.2032533 ,
#        0.24753487, 0.72995265, 0.88343932, 0.59121634, 0.64550128,
#        0.31208857, 0.9278895 , 0.35547545, 0.5649058 , 0.71168193,
#        0.46090419, 0.45519227, 0.24822037, 0.24045865, 0.75198201,
#        0.78764212, 0.10406525, 0.5522581 , 0.74473047, 0.83685049,
#        0.49393693, 0.46222606, 0.10424696, 0.62472191, 0.65752451,
#        0.15947091, 0.1725933 , 0.2431549 , 0.37742613, 0.99196524,
#        0.19787225, 0.0794723 , 0.30492472, 0.09708161, 0.12910085])

# %%
p_y = np.random.random(100)
p_y
# Out:
# array([0.87577719, 0.96387649, 0.1899088 , 0.41389897, 0.29410712,
#        0.67438709, 0.43298256, 0.79477575, 0.12367429, 0.7247788 ,
#        0.4578871 , 0.67713607, 0.07516538, 0.81880062, 0.39293961,
#        0.15546654, 0.16407057, 0.83648519, 0.10137201, 0.34759775,
#        0.69348081, 0.76207803, 0.86791167, 0.48289454, 0.86795972,
#        0.00261818, 0.93416427, 0.31036169, 0.68574363, 0.05028922,
#        0.53855464, 0.49913167, 0.79279272, 0.28192861, 0.70475747,
#        0.79211421, 0.98687309, 0.41879847, 0.73310202, 0.3453988 ,
#        0.31090074, 0.10963767, 0.85758989, 0.03584279, 0.25424383,
#        0.2443483 , 0.16488704, 0.25987021, 0.48720728, 0.96742766,
#        0.84579312, 0.80068674, 0.55694736, 0.90783051, 0.77536163,
#        0.89837959, 0.95846105, 0.00175338, 0.11888478, 0.81373792,
#        0.03106191, 0.90445251, 0.24642384, 0.58746982, 0.34841792,
#        0.93323609, 0.44604085, 0.98517085, 0.72931841, 0.08667517,
#        0.90740204, 0.37306378, 0.22998641, 0.6336799 , 0.65656224,
#        0.51796605, 0.67477506, 0.31450251, 0.09594498, 0.96942009,
#        0.51588361, 0.93641153, 0.60573973, 0.2477483 , 0.52262944,
#        0.99535453, 0.05831772, 0.70256393, 0.63831515, 0.12163596,
#        0.39483529, 0.8405883 , 0.87082935, 0.22741254, 0.68765133,
#        0.59007345, 0.24402355, 0.4488538 , 0.45658498, 0.99030722])

# %%
plt.scatter(p_x,p_y)
plt.show()

# %%
data = np.random.randn(10000)
plt.hist(data)
plt.show()

# %%
x = np.linspace(0,10,100)
fig = plt.figure()
plt.plot(x, np.sin(x), '-')
plt.plot(x, np.cos(x), '--')
plt.show()
fig.savefig('test3.png')

# %%
left = np.array([1,2,3,4,5]) 
height = np.array([100,200,300,400,500])
plt.bar(left,height)
plt.show()
